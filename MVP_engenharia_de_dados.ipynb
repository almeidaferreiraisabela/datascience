# %% [markdown]
# <a href="https://colab.research.google.com/github/almeidaferreiraisabela/datascience/blob/main/MVP_engenharia_de_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1. Definição do objetivo, problema e base de dados**
#
# O dataset que será utilizado neste projeto é o Netflix Userbase Dataset, que é uma amostra da base de usuários da Netflix, que apresenta diversos aspectos sobre a assinatura e o consumidor da plataforma.
# Cada linha representa um usuário único, identificado por seu ID. O conjunto de dados inclui informações como o tipo de assinatura do usuário (Básico, Padrão ou Premium), a receita mensal gerada pela assinatura, a data em que ingressou na Netflix (Data de adesão), a data do último pagamento e o país em que estão localizados entre outros dados.
#
#
#  Para mais detalhes sobre este dataset, consulte: https://www.kaggle.com/datasets/arnavsmayan/netflix-userbase-dataset/data
#
# **Informações sobre os atributos:**
#
# User ID - ID do usuário
#
# Subscription Type - Tipo de assinatura (Básico, Padrão ou Premium)
#
# Monthly Revenue - Receita Mensal gerada pelo usuário (USD)
#
# Join Date - Data de adesão da plataforma
#
# Last Payment Date - Data do último pagamento
#
# Country - País no qual o usuário informa
#
# Age - Idade do usuário
#
# Gender - Gênero do usuário (Feminino e Masculino)
#
# Device - O dispositivo usado para acessar a plataforma (Smart TV, Laptop, entre
# outros)
#
# Plan Duration - Tempo de duração do plano
#
#
# **Objetivo:**
#
# O objetivo é estruturar um pipeline para, a partir disso, fazer uma análise do tipo de assinatura contratada pelos usuários. A estruturação de um pipeline poderá ajudar a empresa a melhorar o seu desempenho no processamentos de dados e consequentemente aprimorar seus estudos e análises.

# %% [markdown]
# ## **2. Carga de Dados**
#
# A plataforma Kaggle foi utilizada para buscar a base de dados "Netflix Userbase". Após realizar o download para a pasta local, o arquivo ZIP foi extraído, acessando os dados. Em seguida, o Databricks foi utilizado, carregando a base de dados diretamente do repositório do GitHub.
#
# ![1 site base de dados.png](data:image/png;base64,...)

# %% [markdown]
# ![2 download da base de dados.png](data:image/png;base64,...)

# %% [markdown]
# # **3. Modelagem, Carga e Transformação de Dados**
#
# **3.1 - Criação de Cluster**
#
# Neste passo, foi utilizado o Databricks para criar clusters. Essa ferramenta é excelente e nos permite configurar e gerenciar recursos de computação de maneira flexível e conforme a necessidade. Isso é fundamental para lidar com grandes quantidades de dados e realizar processos de ETL de forma eficiente.
#
# Ao concentrar a modelagem de ETL no Databricks, pode-se aproveitar a automação de fluxos de trabalho, monitoramento avançado de desempenho e a capacidade de dimensionar recursos automaticamente conforme necessário. Isso assegura eficiência e confiabilidade em todo o processo de preparação de dados.
#
# ![3 criando cluster.png](data:image/png;base64,...)

# %% [markdown]
# **3.2 - Criando Notebook**
#
# Foi criado um Notebook no Databricks para desenvolver a análise dos dados de forma interativa e eficiente, no qual pode-se realizar transformações nos dados, extração e carga, que são as etapas do ETL.
#
# ![4 Criando um notebook no databricks.png](data:image/png;base64,...)

# %% [markdown]
# **3.3 - Importando a base do Github e modificando por código no Databricks**
#
# ![5 rodando o codigo.png](data:image/png;base64,...)

# %% [markdown]
# **3.4 - Resultado**
#
# ![7 resultados part 2.png](data:image/png;base64,...)![6 resultados.png](data:image/png;base64,...)

# %% [markdown]
# **3.5 - Catálogo**
#
# ![8 catalogo.png](data:image/png;base64,...)

# %% [markdown]
# **3.6 - Salvando a base de dados**
#
# ![9 base de dados salva.png](data:image/png;base64,...)

# %% [markdown]
# ![10 base de dados salva part 2.png](data:image/png;base64,...)

# %% [markdown]
# **3.7 - Gerando informações analíticas**
#
# ![11 rodando codigo do grafico.png](data:image/png;base64,...)

# %% [markdown]
# **3.8 - Resultado da Análise**
#
# ![12 resultado codigo grafico.png](data:image/png;base64,...)

# %% [markdown]
# # **4. Conclusão**
#
# Neste trabalho, o Databricks foi utilizado para todo o processo de ETL, começando pela extração da base de dados. A base foi selecionada através da plataforma Kaggle, e o download foi realizado para a área de trabalho. Posteriormente, optou-se por utilizar o repositório do GitHub para continuar o tratamento dos dados.
#
# Na fase de extração, poderiam também ser utilizadas plataformas de armazenamento de dados como o AWS, Google Cloud Storage ou Wasabi.
#
# No Databricks, foram aplicadas as formatações necessárias, conforme representado pelos prints do subgrupo 3.3.
#
# Para finalizar o MVP, a base de dados tratada foi armazenada dentro da própria plataforma, permitindo análises futuras.
